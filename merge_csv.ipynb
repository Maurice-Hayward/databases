# %%
import pandas as pd

# %%
s3 = pd.read_csv("./newCharacterListImgFix.csv")

# %%
s4 = pd.read_csv("./char_ hero_villian.csv")

# %%
merged = s4.merge(s3, on="ID", how="outer")

# %%
merged
# Out:
#           ID    status    sex  \
# 0    1011149   Neutral  Woman
# 1    1010713   Neutral    Man
# 2    1009647   Neutral    Man
# 3    1009648  Villains    Man
# 4    1011115   Neutral    Man
# 5    1009650   Neutral    Man
# 6    1011162  Villains    Man
# 7    1009651  Villains    Man
# 8    1010819    Heroes    Man
# 9    1011003   Neutral    Man
# 10   1009652  Villains    Man
# 11   1010714   Neutral    Man
# 12   1010699   Neutral    Man
# 13   1009146  Villains    Man
# 14   1009148  Villains    Man
# 15   1009149  Villains    Man
# 16   1011266    Heroes    Man
# 17   1010354    Heroes    Man
# 18   1010846    Heroes    Man
# 19   1011297   Neutral    Man
# 20   1011031    Heroes    Man
# 21   1009150    Heroes    Man
# 22   1011175    Heroes    Man
# 23   1011136    Heroes    Man
# 24   1011176    Heroes    Man
# 25   1010870    Heroes    Man
# 26   1009240   Neutral    Man
# 27   1011120    Heroes    Man
# 28   1010836   Neutral    Man
# 29   1010755  Villains    Man
# ...

# %%
merged.to_csv("merged_char.csv")
